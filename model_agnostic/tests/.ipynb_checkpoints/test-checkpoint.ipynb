# %%
from example_keras import SimpleResNet50
data = SimpleResNet50(None)

# %%
from example_keras import SimpleResNet50
preprocessed_data = data.preprocessing("uploads/a.jpg")

# %%
data.predict(preprocessed_data)

# %%
data.result
# Out:
# array([[5.12410679e-07, 6.07107859e-06, 7.10811355e-06, 2.09975610e-06,
#         4.77653248e-06, 9.61621299e-06, 1.38411610e-06, 3.41063860e-05,
#         1.04969076e-05, 2.25560530e-06, 2.87772906e-07, 6.77406933e-06,
#         1.01325195e-05, 1.09612631e-06, 5.98564554e-07, 9.27289818e-07,
#         1.93114460e-07, 4.13739059e-07, 4.08053802e-06, 4.68680037e-06,
#         2.25732336e-07, 4.51064004e-08, 1.20725488e-07, 3.15943248e-06,
#         1.51015070e-06, 3.46961514e-07, 1.27403905e-06, 3.12267457e-06,
#         4.68412111e-07, 3.97902431e-06, 1.59604735e-06, 4.30682775e-07,
#         6.42699035e-07, 4.64706659e-07, 3.00011976e-07, 2.91607762e-07,
#         2.95976406e-06, 4.62229252e-07, 4.10744065e-07, 2.63011498e-06,
#         1.38197129e-06, 1.50817300e-06, 3.17725210e-07, 1.43919385e-06,
#         1.66519783e-06, 2.57618831e-06, 1.24963515e-06, 7.18069202e-07,
#         9.66588141e-06, 4.33227370e-07, 4.16455492e-07, 9.70652181e-05,
# ...

# %%
data.process_result()
# Out:
# [('n04326547', 'stone_wall', 0.25122654),
#  ('n09246464', 'cliff', 0.19599476),
#  ('n09399592', 'promontory', 0.14866522)]

# %%
keras1 = __import__('keras')
# Out:
# Using TensorFlow backend.

# %%
keras1.models
# Out:
# <module 'keras.models' from '/Users/isaac/.local/lib/python3.6/site-packages/keras/models.py'>

# %%
image = getattr(__import__('keras.preprocessing', fromlist=['image']), 'image')

# %%
preprocessed_data
# Out:
# array([[[[ -80.939    ,  -77.779    ,  -67.68     ],
#          [ -84.939    ,  -71.779    ,  -62.68     ],
#          [ -80.939    ,  -66.779    ,  -52.68     ],
#          ...,
#          [-100.939    , -114.779    , -117.68     ],
#          [ -96.939    , -108.779    , -111.68     ],
#          [-103.939    , -116.779    , -119.68     ]],
#
#         [[ -74.939    ,  -76.779    ,  -69.68     ],
#          [-103.939    , -103.779    ,  -93.68     ],
#          [-103.939    , -104.779    ,  -92.68     ],
#          ...,
#          [ -99.939    , -113.779    , -111.68     ],
#          [ -99.939    , -111.779    , -108.68     ],
#          [-101.939    , -112.779    , -111.68     ]],
#
#         [[ -92.939    , -107.779    , -102.68     ],
#          [-103.939    , -107.779    , -100.68     ],
#          [ -91.939    ,  -94.779    ,  -84.68     ],
#          ...,
#          [ -99.939    , -111.779    , -108.68     ],
#          [ -93.939    , -105.779    , -102.68     ],
# ...

# %%
import torch 
#checkpoint = torch.load("weight_share/model.pth.tar", map_location=lambda storage, loc: storage)
 
class DenseNet121(nn.Module):
    """Model modified.
    The architecture of our model is the same as standard DenseNet121
    except the classifier layer which has an additional sigmoid function.
    """
    def __init__(self, out_size):
        super(DenseNet121, self).__init__()
        self.densenet121 = torchvision.models.densenet121(pretrained=True)
        num_ftrs = self.densenet121.classifier.in_features
        self.densenet121.classifier = nn.Sequential(
            nn.Linear(num_ftrs, out_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.densenet121(x)
        return x
import sys 
sys.path.append("..")

# %%
import os
import importlib
import sys 
sys.path.append("..")
from examples2.example_keras import ChexNet

# %%
importlib.reload()
ChexNet("chexnet_files/brucechou1983_CheXNet_Keras_0.3.0_weights.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2d9975e80310> in <module>()
# ----> 1 importlib.reload(example_keras)
#       2 ChexNet("chexnet_files/brucechou1983_CheXNet_Keras_0.3.0_weights.h5")
#
# NameError: name 'example_keras' is not defined
